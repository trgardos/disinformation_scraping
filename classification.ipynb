# %% [markdown]
# ### Importing and preparing classifier

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
import pickle

# %%
with open('models/CARDS_Logistic_Classifier.pkl', 'rb') as f:
    logit = pickle.load(f)

vectorizer = logit['vectorizer']
clf = logit['clf']
le = logit['label_encoder']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.23.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.23.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /var/folders/px/4r2jc78x1h748q29m317jc6w0000gn/T/ipykernel_59743/4183512671.py:2: DeprecationWarning: Please use `csr_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.csr` namespace is deprecated.
#   logit = pickle.load(f)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.23.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.23.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ### Classifying AEI claims

# %%
aei_df = pd.read_csv("scrapers/data/AEI.csv")
print(aei_df.shape)
aei_df.head()
# Out:
# (29, 7)
#                                                TITLE  \
# 0  From Environmentalism to Climate Catastrophism...
# 1   Letter: Electric Vehicles Won’t Save the Climate
# 2            Earth Day 2023: Utterly Bereft of Ideas
# 3  OPEC Remains an Obstacle for Biden’s Green-Ene...
# 4  Comment to the Department of Energy: Proposed ...
#
#                                AUTHOR  \
# 0                        Ruy Teixeira
# 1                     Benjamin Zycher
# 2                     Benjamin Zycher
# 3  Benjamin Zycher, James Pethokoukis
# 4                     Benjamin Zycher
#
#                                              CONTENT            DATE  \
# 0  Key Points\n\nThe environmental movement has a...    May 10, 2023
# 1  Note: This letter to the editor appeared in th...  April 26, 2023
# 2  Earth Day falls on April 22 — Lenin’s birthday...  April 21, 2023
# 3  Can it surprise anyone that the multiple Biden...  April 17, 2023
# 4  Summary\n\nThe estimates on benefits and costs...  April 14, 2023
#
#         TYPE THINK_TANK                                               LINK
# 0     Report        AEI  https://www.aei.org/research-products/report/f...
# 1    Article        AEI  https://www.aei.org/articles/letter-electric-v...
# 2    Article        AEI  https://www.aei.org/articles/earth-day-2023-ut...
# 3    Article        AEI  https://www.aei.org/articles/opec-remains-an-o...
# 4  Testimony        AEI  https://www.aei.org/research-products/testimon...

# %%
aei_df["CONTENT"] = aei_df["CONTENT"].str.split("\n\n") #Split each entry into a list of paragraphs.

# %%
classifications = []
for paragraphs in aei_df["CONTENT"]:
    if type(paragraphs) is float: #Some empty parapgrahs return an empty float instead of a list. No claim. 
        classifications.append([])
    else:
        X = vectorizer.transform(paragraphs) 
        predictions = clf.predict(X) #Predict the claim of each paragraph

        claim_classifications = list(le.inverse_transform(predictions))
        classifications.append(claim_classifications)  

aei_df["CLAIMS"] = classifications #adds a row with a list of the claims made corresponding to each paragraph in the article.
aei_df.head()
# Out:
#                                                TITLE  \
# 0  From Environmentalism to Climate Catastrophism...
# 1   Letter: Electric Vehicles Won’t Save the Climate
# 2            Earth Day 2023: Utterly Bereft of Ideas
# 3  OPEC Remains an Obstacle for Biden’s Green-Ene...
# 4  Comment to the Department of Energy: Proposed ...
#
#                                AUTHOR  \
# 0                        Ruy Teixeira
# 1                     Benjamin Zycher
# 2                     Benjamin Zycher
# 3  Benjamin Zycher, James Pethokoukis
# 4                     Benjamin Zycher
#
#                                              CONTENT            DATE  \
# 0  [Key Points, The environmental movement has al...    May 10, 2023
# 1  [Note: This letter to the editor appeared in t...  April 26, 2023
# 2  [Earth Day falls on April 22 — Lenin’s birthda...  April 21, 2023
# 3  [Can it surprise anyone that the multiple Bide...  April 17, 2023
# 4  [Summary, The estimates on benefits and costs ...  April 14, 2023
#
#         TYPE THINK_TANK                                               LINK  \
# 0     Report        AEI  https://www.aei.org/research-products/report/f...
# 1    Article        AEI  https://www.aei.org/articles/letter-electric-v...
# 2    Article        AEI  https://www.aei.org/articles/earth-day-2023-ut...
# 3    Article        AEI  https://www.aei.org/articles/opec-remains-an-o...
# 4  Testimony        AEI  https://www.aei.org/research-products/testimon...
#
#                                               CLAIMS
# 0  [0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, ...
# 1                               [0_0, 4_2, 0_0, 0_0]
# 2  [0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 4_4, ...
# 3           [0_0, 0_0, 0_0, 0_0, 5_1, 0_0, 0_0, 0_0]
# 4                     [0_0, 0_0, 0_0, 5_1, 0_0, 0_0]

# %% [markdown]
# ### Heartland

# %%
heartland_df = pd.read_csv("scrapers/data/heartland.csv")
print(heartland_df.shape)
heartland_df.head()
# Out:
# (249, 7)
#                                                TITLE  \
# 0  Research & Commentary: Anti-Economic Boycott B...
# 1  Research & Commentary: Anti-ESG Bill in North ...
# 2  Energy at a Glance: Fracking for Oil and Natur...
# 3  Environmental, Social, and Governance (ESG) Sc...
# 4  Research & Commentary: EPA Finds Greenhouse Ga...
#
#                        AUTHOR  \
# 0                  Tim Benson
# 1  Tim Benson, Jack McPherrin
# 2               Linnea Lueken
# 3              Jack McPherrin
# 4                  Tim Benson
#
#                                              CONTENT            DATE  \
# 0  Legislation in the Alabama Senate (SB 261) wou...     May 2, 2023
# 1  Legislation in the North Carolina House of Rep...     May 2, 2023
# 2  For the full PDF of this policy tip sheet, cli...  April 26, 2023
# 3  Environmental, social, and governance (ESG) sc...  April 26, 2023
# 4  The U.S. Environmental Protection Agency’s (EP...  April 13, 2023
#
#           TYPE THINK_TANK                                               LINK
# 0  PUBLICATION  Heartland  https://heartland.org/publications/research-co...
# 1  PUBLICATION  Heartland  https://heartland.org/publications/research-co...
# 2  PUBLICATION  Heartland  https://heartland.org/publications/energy-at-a...
# 3  PUBLICATION  Heartland  https://heartland.org/publications/environment...
# 4  PUBLICATION  Heartland  https://heartland.org/publications/research-co...

# %%
heartland_df["CONTENT"] = heartland_df["CONTENT"].str.split("\n\n")

# %%
classifications = []
for paragraphs in heartland_df["CONTENT"]:
    if type(paragraphs) is float: #Some empty parapgrahs return an empty float instead of a list. No claim.
        classifications.append([])
    else:
        X = vectorizer.transform(paragraphs)
        predictions = clf.predict(X)

        claim_classifications = list(le.inverse_transform(predictions))
        classifications.append(claim_classifications)   
heartland_df["CLAIMS"] = classifications #adds a row with a list of the claims made corresponding to each paragraph in the article.
heartland_df.head()
# Out:
#                                                TITLE  \
# 0  Research & Commentary: Anti-Economic Boycott B...
# 1  Research & Commentary: Anti-ESG Bill in North ...
# 2  Energy at a Glance: Fracking for Oil and Natur...
# 3  Environmental, Social, and Governance (ESG) Sc...
# 4  Research & Commentary: EPA Finds Greenhouse Ga...
#
#                        AUTHOR  \
# 0                  Tim Benson
# 1  Tim Benson, Jack McPherrin
# 2               Linnea Lueken
# 3              Jack McPherrin
# 4                  Tim Benson
#
#                                              CONTENT            DATE  \
# 0  [Legislation in the Alabama Senate (SB 261) wo...     May 2, 2023
# 1  [Legislation in the North Carolina House of Re...     May 2, 2023
# 2  [For the full PDF of this policy tip sheet, cl...  April 26, 2023
# 3  [Environmental, social, and governance (ESG) s...  April 26, 2023
# 4  [The U.S. Environmental Protection Agency’s (E...  April 13, 2023
#
#           TYPE THINK_TANK                                               LINK  \
# 0  PUBLICATION  Heartland  https://heartland.org/publications/research-co...
# 1  PUBLICATION  Heartland  https://heartland.org/publications/research-co...
# 2  PUBLICATION  Heartland  https://heartland.org/publications/energy-at-a...
# 3  PUBLICATION  Heartland  https://heartland.org/publications/environment...
# 4  PUBLICATION  Heartland  https://heartland.org/publications/research-co...
#
#                                               CLAIMS
# 0  [0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, ...
# 1  [0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, 0_0, ...
# 2      [0_0, 0_0, 0_0, 4_5, 0_0, 0_0, 4_5, 0_0, 0_0]
# 3                     [0_0, 0_0, 0_0, 0_0, 0_0, 0_0]
# 4  [0_0, 3_3, 0_0, 4_5, 0_0, 0_0, 0_0, 0_0, 4_5, ...
